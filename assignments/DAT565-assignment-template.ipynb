# %% [markdown]
# # DAT565 Assignment X – Group 43

# %% [markdown]
# - Student 1 - Luca Modica - (5 hours)
# - Student 2 - Hugo Alves Henriques E Silva - (5 hours)
# - Student 3 - YenPo Lin - (5 hours)

# %% [markdown]
# Month Day, Year

# %% [markdown]
# ## Introduction

# %% [markdown]
# INTRODUCTION HERE

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# config inline plots
# %matplotlib inline

# set seaborn style
sns.set_style('darkgrid')
